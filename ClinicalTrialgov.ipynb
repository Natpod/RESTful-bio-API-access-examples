# %% [markdown]
# Clinicaltrials.gov

# %%
import pandas as pd
import numpy as np
import requests

# %%
curl -X GET "https://clinicaltrials.gov/api/v2/studies?format=json&markupFormat=markdown&query.cond=Parkinson&query.intr=DRUG+AND+sildenafil&fields=NCTId%7CCondition%7CInterventionName%7CPhase" \
 -H "accept: application/json" \

# %%
ICD10_cases = pd.read_excel("C:\\Users\\naata\\Downloads\\Supplementary Material Repository (SMR)_Generating DR_TOTAL_ICD10CM_CASES.xlsx")
MESH_cases = pd.read_excel("C:\\Users\\naata\\Downloads\\TOTAL_MSH_INH_CASES.xlsx")

# %%
ICD10_cases.shape
# Out:
# (6342, 10)

# %%
res_df_MESH
# Out:
#        identificationModule  \
# 0  {'nctId': 'NCT00461630'}
# 1  {'nctId': 'NCT04679389'}
#
#                                     conditionsModule  \
# 0  {'conditions': ['Cardiovascular Disease', 'Per...
# 1              {'conditions': ['Pmm2-CDG', 'CDG1A']}
#
#                        designModule  \
# 0            {'phases': ['PHASE3']}
# 1  {'phases': ['PHASE2', 'PHASE3']}
#
#                              armsInterventionsModule
# 0  {'interventions': [{'name': 'ER niacin/laropip...
# 1  {'interventions': [{'name': 'Placebo'}, {'name...

# %%
res_df_MESH = pd.DataFrame()

for Ohe_D, Ohe_Dr in MESH_cases[["Untreated disease", "Drug"]].drop_duplicates().values.tolist():
    base_url = f"https://clinicaltrials.gov/api/v2/studies?format=json&markupFormat=markdown&query.cond={Ohe_D}&query.intr=DRUG+AND+{Ohe_Dr}&fields=NCTId%7CCondition%7CInterventionName%7CPhase"
    request_url = base_url
    r = requests.get(request_url, headers={ "Accept" : "application/json"})

    if not r.ok:
      r.raise_for_status()
      sys.exit()

    responseBody = r.json()
    if len(responseBody["studies"]) != 0:
        res_df_MESH = pd.concat((res_df_MESH, pd.DataFrame.from_dict(responseBody["studies"][0].values())), ignore_index=True)
        print(responseBody)
# Out:
# {'studies': [{'protocolSection': {'identificationModule': {'nctId': 'NCT00461630'}, 'conditionsModule': {'conditions': ['Cardiovascular Disease', 'Peripheral Arterial Disease', 'Diabetes Mellitus', 'Coronary Heart Disease']}, 'designModule': {'phases': ['PHASE3']}, 'armsInterventionsModule': {'interventions': [{'name': 'ER niacin/laropiprant'}, {'name': 'simvastatin'}, {'name': 'ezetimibe/simvastatin'}]}}}]}
# {'studies': [{'protocolSection': {'identificationModule': {'nctId': 'NCT04679389'}, 'conditionsModule': {'conditions': ['Pmm2-CDG', 'CDG1A']}, 'designModule': {'phases': ['PHASE2', 'PHASE3']}, 'armsInterventionsModule': {'interventions': [{'name': 'Placebo'}, {'name': 'Acetazolamide'}]}}}]}
# ...

# %%
# OHE
ICD10_cases_OHE = pd.read_excel("C:\\Users\\naata\\Downloads\\Supplementary Material Repository (SMR)_Generating DR_TOTAL_ICD10CM_CASES.xlsx", sheet_name='Embedding - OneHot')
MESH_cases_OHE = pd.read_excel("C:\\Users\\naata\\Downloads\\TOTAL_MSH_INH_CASES.xlsx", sheet_name='Embedding - OneHot')

# %%
ICD_res_OHE = pd.DataFrame()

for Ohe_D, Ohe_Dr in ICD10_cases_OHE[["Untreated disease", "Drug"]].drop_duplicates().values.tolist():
    base_url = f"https://clinicaltrials.gov/api/v2/studies?format=json&markupFormat=markdown&query.cond={Ohe_D}&query.intr=DRUG+AND+{Ohe_Dr}&fields=NCTId%7CCondition%7CInterventionName%7CPhase"
    request_url = base_url
    r = requests.get(request_url, headers={ "Accept" : "application/json"})

    if not r.ok:
      r.raise_for_status()
      sys.exit()

    responseBody = r.json()
    if len(responseBody["studies"]) != 0:
        ICD_res_OHE = pd.concat((ICD_res_OHE, pd.DataFrame.from_dict(responseBody["studies"][0].values())), ignore_index=True)
        print(responseBody)

# %%
MESH_res_OHE = pd.DataFrame()

for Ohe_D, Ohe_Dr in MESH_cases_OHE[[MESH_cases_OHE.columns[0], MESH_cases_OHE.columns[2]]].drop_duplicates().values.tolist():
    base_url = f"https://clinicaltrials.gov/api/v2/studies?format=json&markupFormat=markdown&query.cond={Ohe_D}&query.intr=DRUG+AND+{Ohe_Dr}&fields=NCTId%7CCondition%7CInterventionName%7CPhase"
    request_url = base_url
    r = requests.get(request_url, headers={ "Accept" : "application/json"})

    if not r.ok:
      r.raise_for_status()
      sys.exit()

    responseBody = r.json()
    if len(responseBody["studies"]) != 0:
        MESH_res_OHE = pd.concat((MESH_res_OHE, pd.DataFrame.from_dict(responseBody["studies"][0].values())), ignore_index=True)
        print(responseBody)
# Out:
# {'studies': [{'protocolSection': {'identificationModule': {'nctId': 'NCT06065852'}, 'conditionsModule': {'conditions': ['Adenine Phosphoribosyltransferase Deficiency', 'AH Amyloidosis', 'AHL Amyloidosis', 'AL Amyloidosis', 'Alport Syndrome', 'Atypical Hemolytic Uremic Syndrome', 'Autoimmune Distal Renal Tubular Acidosis', 'Autosomal Recessive Proximal Renal Tubular Acidosis', 'Autosomal Recessive Distal Renal Tubular Acidosis', 'Autosomal Dominant Polycystic Kidney Disease', 'Autosomal Recessive Polycystic Kidney Disease', 'Bartter Syndrome', 'BK Nephropathy', 'C3 Glomerulopathy With Monoclonal Gammopathy', 'C3 Glomerulopathy', 'Calciphylaxis', 'Crystalglobulinaemia', 'Crystal-storing Histiocytosis', 'Cystinosis', 'Cystinuria', 'Dense Deposit Disease', 'Dent Disease', 'Denys-Drash Syndrome', 'Dominant Hypophosphataemia With Nephrolithiasis and/or Osteoporosis', 'Drug Induced Fanconi Syndrome', 'Drug-Induced Hypomagnesemia', 'Drug-Induced Nephrogenic Diabetes Insipidus', 'Epilepsy, At
# ...

# %%
# SGT
ICD10_cases_SGT = pd.read_excel("C:\\Users\\naata\\Downloads\\Supplementary Material Repository (SMR)_Generating DR_TOTAL_ICD10CM_CASES.xlsx", sheet_name='Embedding - SGT')
MESH_cases_SGT = pd.read_excel("C:\\Users\\naata\\Downloads\\TOTAL_MSH_INH_CASES.xlsx", sheet_name='Embedding - SGT')

# %%
ICD_res_SGT = pd.DataFrame()

for Ohe_D, Ohe_Dr in ICD10_cases_SGT[["Untreated disease", "Drug"]].drop_duplicates().values.tolist():
    base_url = f"https://clinicaltrials.gov/api/v2/studies?format=json&markupFormat=markdown&query.cond={Ohe_D}&query.intr=DRUG+AND+{Ohe_Dr}&fields=NCTId%7CCondition%7CInterventionName%7CPhase"
    request_url = base_url
    r = requests.get(request_url, headers={ "Accept" : "application/json"})

    if not r.ok:
      r.raise_for_status()
      sys.exit()

    responseBody = r.json()
    if len(responseBody["studies"]) != 0:
        ICD_res_SGT = pd.concat((ICD_res_SGT, pd.DataFrame.from_dict(responseBody["studies"][0].values())), ignore_index=True)
        print(responseBody)
# Out:
# {'studies': [{'protocolSection': {'identificationModule': {'nctId': 'NCT00079599'}, 'conditionsModule': {'conditions': ['HIV Infections', 'AIDS']}, 'designModule': {'phases': ['PHASE2']}, 'armsInterventionsModule': {'interventions': [{'name': 'L-carnitine'}, {'name': 'Placebo'}]}}}, {'protocolSection': {'identificationModule': {'nctId': 'NCT00187733'}, 'conditionsModule': {'conditions': ['Carnitine Transporter Deficiency']}, 'designModule': {}, 'armsInterventionsModule': {'interventions': [{'name': 'Fasting blood and urine collection'}]}}}, {'protocolSection': {'identificationModule': {'nctId': 'NCT05948124'}, 'conditionsModule': {'conditions': ['Carnitine Deficiency Due to Hemodialysis']}, 'designModule': {'phases': ['EARLY_PHASE1']}, 'armsInterventionsModule': {'interventions': [{'name': 'L-carnitine'}, {'name': 'isotonic saline'}]}}}, {'protocolSection': {'identificationModule': {'nctId': 'NCT01783041'}, 'conditionsModule': {'conditions': ['Prematurity', 'Neurodevelopmental Disord
# ...

# %%
MESH_res_SGT = pd.DataFrame()

for Ohe_D, Ohe_Dr in MESH_cases_SGT[[MESH_cases_SGT.columns[0], MESH_cases_SGT.columns[2]]].drop_duplicates().values.tolist():
    base_url = f"https://clinicaltrials.gov/api/v2/studies?format=json&markupFormat=markdown&query.cond={Ohe_D}&query.intr=DRUG+AND+{Ohe_Dr}&fields=NCTId%7CCondition%7CInterventionName%7CPhase"
    request_url = base_url
    r = requests.get(request_url, headers={ "Accept" : "application/json"})

    if not r.ok:
      r.raise_for_status()
      sys.exit()

    responseBody = r.json()
    if len(responseBody["studies"]) != 0:
        MESH_res_SGT = pd.concat((MESH_res_SGT, pd.DataFrame.from_dict(responseBody["studies"][0].values())), ignore_index=True)
        print(responseBody)
# Out:
# {'studies': [{'protocolSection': {'identificationModule': {'nctId': 'NCT02171104'}, 'conditionsModule': {'conditions': ['Mucopolysaccharidosis Disorders', 'Hurler Syndrome', 'Hunter Syndrome', 'Maroteaux Lamy Syndrome', 'Sly Syndrome', 'Alpha-Mannosidosis', 'Fucosidosis', 'Aspartylglucosaminuria', 'Glycoprotein Metabolic Disorders', 'Sphingolipidoses', 'Recessive Leukodystrophies', 'Globoid Cell Leukodystrophy', 'Metachromatic Leukodystrophy', 'Niemann-Pick B', 'Niemann-Pick C Subtype 2', 'Sphingomyelin Deficiency', 'Peroxisomal Disorders', 'Adrenoleukodystrophy With Cerebral Involvement', 'Zellweger Syndrome', 'Neonatal Adrenoleukodystrophy', 'Infantile Refsum Disease', 'Acyl-CoA Oxidase Deficiency', 'D-Bifunctional Enzyme Deficiency', 'Multifunctional Enzyme Deficiency', 'Alpha-methylacyl-CoA Racmase Deficiency', 'Mitochondrial Neurogastrointestingal Encephalopathy', 'Severe Osteopetrosis', 'Hereditary Leukoencephalopathy With Axonal Spheroids (HDLS; CSF1R Mutation)', 'Inherited Me
# ...

# %%
# ProtBERT

ICD10_cases_BERT = pd.read_excel("C:\\Users\\naata\\Downloads\\Supplementary Material Repository (SMR)_Generating DR_TOTAL_ICD10CM_CASES.xlsx", sheet_name='Embedding - BERT')
MESH_cases_BERT = pd.read_excel("C:\\Users\\naata\\Downloads\\TOTAL_MSH_INH_CASES.xlsx", sheet_name='Embedding - BERT')

# %%
ICD_res_BERT = pd.DataFrame()

for Ohe_D, Ohe_Dr in ICD10_cases_BERT[["Untreated disease", "Drug"]].drop_duplicates().values.tolist():
    base_url = f"https://clinicaltrials.gov/api/v2/studies?format=json&markupFormat=markdown&query.cond={Ohe_D}&query.intr=DRUG+AND+{Ohe_Dr}&fields=NCTId%7CCondition%7CInterventionName%7CPhase"
    request_url = base_url
    r = requests.get(request_url, headers={ "Accept" : "application/json"})

    if not r.ok:
      r.raise_for_status()
      sys.exit()

    responseBody = r.json()
    if len(responseBody["studies"]) != 0:
        ICD_res_BERT = pd.concat((ICD_res_BERT, pd.DataFrame.from_dict(responseBody["studies"][0].values())), ignore_index=True)
        print(responseBody)

# %%
MESH_res_BERT = pd.DataFrame()

for Ohe_D, Ohe_Dr in MESH_cases_BERT[[MESH_cases_BERT.columns[0], MESH_cases_BERT.columns[2]]].drop_duplicates().values.tolist():
    base_url = f"https://clinicaltrials.gov/api/v2/studies?format=json&markupFormat=markdown&query.cond={Ohe_D}&query.intr=DRUG+AND+{Ohe_Dr}&fields=NCTId%7CCondition%7CInterventionName%7CPhase"
    request_url = base_url
    r = requests.get(request_url, headers={ "Accept" : "application/json"})

    if not r.ok:
      r.raise_for_status()
      sys.exit()

    responseBody = r.json()
    if len(responseBody["studies"]) != 0:
        MESH_res_BERT = pd.concat((MESH_res_BERT, pd.DataFrame.from_dict(responseBody["studies"][0].values())), ignore_index=True)
        print(responseBody)
# Out:
# {'studies': [{'protocolSection': {'identificationModule': {'nctId': 'NCT04679389'}, 'conditionsModule': {'conditions': ['Pmm2-CDG', 'CDG1A']}, 'designModule': {'phases': ['PHASE2', 'PHASE3']}, 'armsInterventionsModule': {'interventions': [{'name': 'Placebo'}, {'name': 'Acetazolamide'}]}}}]}
# {'studies': [{'protocolSection': {'identificationModule': {'nctId': 'NCT04679389'}, 'conditionsModule': {'conditions': ['Pmm2-CDG', 'CDG1A']}, 'designModule': {'phases': ['PHASE2', 'PHASE3']}, 'armsInterventionsModule': {'interventions': [{'name': 'Placebo'}, {'name': 'Acetazolamide'}]}}}]}

# %%
# SeqVec

ICD10_cases_SeqVec = pd.read_excel("C:\\Users\\naata\\Downloads\\Supplementary Material Repository (SMR)_Generating DR_TOTAL_ICD10CM_CASES.xlsx", sheet_name='Embedding - SeqVec')
MESH_cases_SeqVec = pd.read_excel("C:\\Users\\naata\\Downloads\\TOTAL_MSH_INH_CASES.xlsx", sheet_name='Embedding - SeqVec')

# %%
ICD_res_SeqVec = pd.DataFrame()

for Ohe_D, Ohe_Dr in ICD10_cases_SeqVec[["Untreated disease", "Drug"]].drop_duplicates().values.tolist():
    base_url = f"https://clinicaltrials.gov/api/v2/studies?format=json&markupFormat=markdown&query.cond={Ohe_D}&query.intr=DRUG+AND+{Ohe_Dr}&fields=NCTId%7CCondition%7CInterventionName%7CPhase"
    request_url = base_url
    r = requests.get(request_url, headers={ "Accept" : "application/json"})

    if not r.ok:
      r.raise_for_status()
      sys.exit()

    responseBody = r.json()
    if len(responseBody["studies"]) != 0:
        ICD_res_SeqVec = pd.concat((ICD_res_SeqVec, pd.DataFrame.from_dict(responseBody["studies"][0].values())), ignore_index=True)
        print(responseBody)

# %%
MESH_res_SeqVec = pd.DataFrame()

for Ohe_D, Ohe_Dr in MESH_cases_SeqVec[[MESH_cases_SeqVec.columns[0], MESH_cases_SeqVec.columns[2]]].drop_duplicates().values.tolist():
    base_url = f"https://clinicaltrials.gov/api/v2/studies?format=json&markupFormat=markdown&query.cond={Ohe_D}&query.intr=DRUG+AND+{Ohe_Dr}&fields=NCTId%7CCondition%7CInterventionName%7CPhase"
    request_url = base_url
    r = requests.get(request_url, headers={ "Accept" : "application/json"})

    if not r.ok:
      r.raise_for_status()
      sys.exit()

    responseBody = r.json()
    if len(responseBody["studies"]) != 0:
        MESH_res_SeqVec = pd.concat((MESH_res_SeqVec, pd.DataFrame.from_dict(responseBody["studies"][0].values())), ignore_index=True)
        print(responseBody)
# Out:
# {'studies': [{'protocolSection': {'identificationModule': {'nctId': 'NCT05711693'}, 'conditionsModule': {'conditions': ['Hypertension', 'Aortic Aneurysm', 'Bicuspid Aortic Valve', 'Marfan Syndrome', 'Aortic Dilatation']}, 'designModule': {'phases': ['NA']}, 'armsInterventionsModule': {'interventions': [{'name': 'Laser doppler vibrometry (LDV), heart(cordium) carotid pulse wave velocity (ccPWV)'}, {'name': 'Blood pressure and heart rate measurement'}, {'name': 'carotid to femoral PWW measurement'}, {'name': 'Questionnaire completion'}]}}}]}
# ...

# %%
# Downstream analysis
MESH_res_OHE["Embedding-Subset"] = "OHE // MESH-INH"
ICD_res_OHE["Embedding-Subset"] = "OHE // ICD-NC"

MESH_res_SGT["Embedding-Subset"] = "SGT // MESH-INH"
ICD_res_SGT["Embedding-Subset"] = "SGT // ICD-NC"

MESH_res_BERT["Embedding-Subset"] = "BERT // MESH-INH"
ICD_res_BERT["Embedding-Subset"] = "BERT // ICD-NC"

MESH_res_SeqVec["Embedding-Subset"] = "SeqVec // MESH-INH"
ICD_res_SeqVec["Embedding-Subset"] = "SeqVec // ICD-NC"

# %%
res_all = pd.concat([MESH_res_OHE,ICD_res_OHE,MESH_res_SGT,ICD_res_SGT,MESH_res_BERT,ICD_res_BERT,MESH_res_SeqVec,ICD_res_SeqVec], ignore_index=True)

# %%
res_all.to_excel("C:\\Users\\naata\\Downloads\\Results_embeddings.xlsx", index=False)

# %%
res_all.to_excel("C:\\Users\\naata\\Downloads\\Results_embeddings.xlsx", index=False)

# %%
bl = pd.concat([res_df, res_df_MESH], ignore_index=True)
bl.to_excel("C:\\Users\\naata\\Downloads\\Results_embeddings_bl.xlsx", index=False)

# %%
for Ohe_D, Ohe_Dr in ICD10_cases[["Untreated disease", "Drug"]].drop_duplicates().values.tolist():
    base_url = f"https://clinicaltrials.gov/api/v2/studies?format=json&markupFormat=markdown&query.cond={Ohe_D}&query.intr=DRUG+AND+{Ohe_Dr}&fields=NCTId%7CCondition%7CInterventionName%7CPhase%7CHasResults"
    request_url = base_url
    r = requests.get(request_url, headers={ "Accept" : "application/json"})

    if not r.ok:
      r.raise_for_status()
      sys.exit()

    responseBody = r.json()
    if len(responseBody["studies"]) != 0:
        print(responseBody)

# %%
base_url = "https://clinicaltrials.gov/api/v2/studies?format=json&markupFormat=markdown&query.cond=Parkinson&query.intr=DRUG+AND+sildenafil&fields=NCTId%7CCondition%7CInterventionName%7CPhase%7CHasResults"
request_url = base_url
r = requests.get(request_url, headers={ "Accept" : "application/json"})

if not r.ok:
  r.raise_for_status()
  sys.exit()

responseBody = r.json()
print(responseBody)
# Out:
# {'studies': [{'protocolSection': {'identificationModule': {'nctId': 'NCT02162979'}, 'conditionsModule': {'conditions': ["Parkinson's Disease"]}, 'designModule': {'phases': ['PHASE2']}, 'armsInterventionsModule': {'interventions': [{'name': 'sildenafil'}, {'name': 'Placebo'}]}}, 'hasResults': True}, {'protocolSection': {'identificationModule': {'nctId': 'NCT01941732'}, 'conditionsModule': {'conditions': ['Parkinsons Disease', 'Erectile Dysfunction']}, 'designModule': {'phases': ['PHASE4']}, 'armsInterventionsModule': {'interventions': [{'name': 'Sildenafil'}]}}, 'hasResults': False}]}

# %% [markdown]
# version 1

# %%
base_url = "https://ClinicalTrials.gov/api/query/study_fields?expr=heart+attack&fields=NCTId,Condition,InterventionName,Phase&fmt=CSV"
request_url = base_url
r = requests.get(request_url, headers={ "Accept" : "application/csv"})

if not r.ok:
  r.raise_for_status()
  sys.exit()

responseBody = r.text
print(responseBody)
# Out:
# "APIVrs: 1.01.05"
# "DataVrs: 2024:02:16 00:00:50.360"
# "Expression: heart attack"
# "NStudiesAvail: 483239"
# "NStudiesFound: 10389"
# "MinRank: 1"
# "MaxRank: 20"
# "NStudiesReturned: 20"
# "Field Names: NCTId,Condition,InterventionName,Phase"
#
# "Rank","NCTId","Condition","InterventionName","Phase"
# 1,"NCT05654389","Telemedicine","Application of teleconsultation for a patient with a provisional diagnosis of myocardial infarction at the district hospital","Not Applicable"
# 2,"NCT01874691","Acute Myocardial Infarction",,
# 3,"NCT03015064","Myocardial Infarction","Myocardial Infarction",
# 4,"NCT01168609","Myocardial Infarction","Primary percutaneous coronary intervention",
# 5,"NCT06038994","Myocardial Infarction, Acute","No intervention",
# 6,"NCT03412435","Myocardial Infarction, Acute|Coronary Stenosis",,
# 7,"NCT04628104","Myocardial Infarction","cardiac magnetic resonance",
# 8,"NCT00632788","Myocardial Infarction","acute myocardial infarction checklist",
# ...

# %%
base_url = "https://ClinicalTrials.gov/api/query/field_values?expr=heart+attack&field=Condition&fmt=CSV"
request_url = base_url
r = requests.get(request_url, headers={ "Accept" : "application/csv"})

if not r.ok:
  r.raise_for_status()
  sys.exit()

responseBody = r.text
print(responseBody)
# Out:
# "APIVrs: 1.01.05"
# "DataVrs: 2024:02:16 00:00:50.360"
# "Expression: heart attack"
# "NStudiesAvail: 483239"
# "NStudiesFound: 10389"
# "MinRank: 1"
# "MaxRank: 483239"
# "NStudiesUsed: 10389"
# "Field: Condition"
# "NUniqueValues: 110664"
# "NUniqueValuesFound: 4660"
# "NStudiesMissingValue: 921"
# "NStudiesFoundMissingValue: 0"
#
# "Index","NStudiesWithValue","NStudiesFoundWithValue","FieldValue"
# 1,1,1,"(STEMI)"
# 2,1,1,"22q Telomere Deletion Syndrome"
# 3,1,1,"3 Vessel Coronary Artery Disease"
# 4,1,1,"a Myocardial Infarction"
# 5,1,1,"A Total of 234 Patients With Acute Coronary Syndrome Who Will Undergo OPCAB."
# 6,12,3,"AAA"
# 7,10,3,"AAA - Abdominal Aortic Aneurysm"
# 8,189,41,"Abdominal Aortic Aneurysm"
# 9,14,2,"Abdominal Aortic Aneurysm (AAA)"
# 10,1,1,"Abdominal Aortic Aneurysm Uncomplicated"
# 11,11,2,"Abdominal Aortic Aneurysm Without Rupture"
# 12,32,9,"Abdominal Aortic Aneurysms"
# 13,73,4,"Abdominal Obesity"
# 14,61,1,"Abdominal Surgery"
# ...
